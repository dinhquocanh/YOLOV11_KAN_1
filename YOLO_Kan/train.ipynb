# %%
pip uninstall ultralytics
# Out:
# WARNING: Skipping ultralytics as it is not installed.
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="EbMdAykfgvbg7Rn7TrhJ")
project = rf.workspace("lamar-university-venef").project("grocery-rfn8l")
version = project.version(3)
dataset = version.download("yolov11")
# Out:
# ^C
#   File "/Users/dangchauky/.pyenv/versions/3.10.13/lib/python3.10/site-packages/pip/_vendor/pyparsing/__init__.py", line 140, in <module>
#     from .core import __diag__, __compat__
#   File "/Users/dangchauky/.pyenv/versions/3.10.13/lib/python3.10/site-packages/pip/_vendor/pyparsing/core.py", line 46, in <module>
#     from .results import ParseResults, _ParseResultsWithOffset
#   File "/Users/dangchauky/.pyenv/versions/3.10.13/lib/python3.10/site-packages/pip/_vendor/pyparsing/results.py", line 3, in <module>
#     import pprint
#   File "/Users/dangchauky/.pyenv/versions/3.10.13/lib/python3.10/pprint.py", line 38, in <module>
#     import dataclasses as _dataclasses
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1006, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 688, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 879, in exec_module
# ...

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="YwVOXU5vYt7vFhKTeQCg")
project = rf.workspace("michael-ringer").project("freiburg-groceries")
version = project.version(10)
dataset = version.download("yolov11")
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.7/86.7 kB 566.6 kB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 1.2 MB/s eta 0:00:00ta 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━ 1.6/4.0 MB 36.0 kB/s eta 0:01:06
# ERROR: Exception:
# Traceback (most recent call last):
#   File "/Users/dangchauky/.pyenv/versions/3.10.13/lib/python3.10/site-packages/pip/_vendor/urllib3/response.py", line 438, in _error_catcher
#     yield
#   File "/Users/dangchauky/.pyenv/versions/3.10.13/lib/python3.10/site-packages/pip/_vendor/urllib3/response.py", line 561, in read
#     data = self._fp_read(amt) if not fp_closed else b""
#   File "/Users/dangchauky/.pyenv/versions/3.10.13/lib/python3.10/site-packages/pip/_vendor/urllib3/response.py", line 527, in _fp_read
#     return self._fp.read(amt) if amt is not None else self._fp.read()
# ...

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="YwVOXU5vYt7vFhKTeQCg")
project = rf.workspace("politeknik-negeri-batam-jtpr2").project("recognize")
version = project.version(1)
dataset = version.download("yolov11")
# Out:
# ...
#   Using cached roboflow-1.1.66-py3-none-any.whl (86 kB)
# ...
#   Using cached numpy-2.2.6-cp310-cp310-macosx_14_0_arm64.whl (5.3 MB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.8/54.8 MB 1.6 MB/s eta 0:00:0000:0100:01m
# ...
#   Using cached python_dotenv-1.1.0-py3-none-any.whl (20 kB)
# ...
#   Using cached requests-2.32.3-py3-none-any.whl (64 kB)
# ...
#   Using cached urllib3-2.4.0-py3-none-any.whl (128 kB)
# ...
#   Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.0/8.0 MB 2.5 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 8.9 MB/s eta 0:00:00
# ...
#   Using cached PyYAML-6.0.2-cp310-cp310-macosx_11_0_arm64.whl (171 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.0/4.0 MB 4.5 MB/s eta 0:00:0000:0100:01
# ...
#   Using cached idna-3.7-py3-none-any.whl (66 kB)
# ...
#   Using cached tqdm-4.67.1-py3-none-any.whl (78 kB)
# ...
#   Using cached certifi-2025.4.26-py3-none-any.whl (159 kB)
# ...

# %%
from ultralytics import YOLO

# Load a COCO-pretrained YOLO11n model
model = YOLO("/Users/dangchauky/Downloads/yolo11KAN.pt")

# Train the model on the COCO8 example dataset for 100 epochs
results = model.train(data="/Users/dangchauky/Downloads/ultralytics_test/ultralytics/cfg/datasets/coco8.yaml", epochs=15, imgsz=640, freeze=0)
# Out:
# New https://pypi.org/project/ultralytics/8.3.152 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.127 🚀 Python-3.11.8 torch-2.4.1 CPU (Apple M3 Pro)
# ...
